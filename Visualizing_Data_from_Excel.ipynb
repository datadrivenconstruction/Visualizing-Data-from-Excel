# %% [markdown]
# <a href="https://colab.research.google.com/github/DataDrivenConstrution/Visualizing-Data-from-Excel/blob/main/Visualizing_Data_from_Excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Reading the "ITEMIZED EXPENSES" sheet
itemized_expenses_df = pd.read_excel("https://datadrivenconstruction.io/wp-content/uploads/2023/08/Free_Construction_Estimate_Template_ProjectManager_ND23.xlsx", sheet_name="ITEMIZED EXPENSES")

# Display the first few rows of the dataframe for review
itemized_expenses_head = itemized_expenses_df.head()

itemized_expenses_head
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
#    Unnamed: 0            Item   Category  Amount
# 0         NaN   Tile flooring  Materials     350
# 1         NaN      Floor glue  Materials      75
# 2         NaN        Flooring  Materials     400
# 3         NaN  Floor caulking  Materials      20
# 4         NaN      Floor trim  Materials      40

# %%
import matplotlib.pyplot as plt

# Grouping the expenses by category and summing the amounts
category_expenses = itemized_expenses_df.groupby("Category")["Amount"].sum()

# Pie chart visualization
plt.figure(figsize=(10, 7))
category_expenses.plot(kind="pie", autopct='%1.1f%%', startangle=90)
plt.title("Distribution of Expenses by Category")
plt.ylabel("")  # Remove the default ylabel for a cleaner look
plt.show()
